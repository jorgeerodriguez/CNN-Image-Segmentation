# %% [markdown]
# # Image Mask Generator code:
#
# ## This code is used to read jpg images, use the SAM library created by Meta AI, select the best mask produced by SAM, adapt it to a correct label format for our CNN model, build a contour around the mask and finally save it as png format.
#
# ### Created by: Jorge Rodriguez
# ### Crated date: July 27th 2024
# ### Last Modified July 31th 2024

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Setting the correct Diretory Structure for Input Images and Targe Masks:

# %%
import os
input_dir = "./images/"
target_dir = "./annotations/trimaps/"
input_img_paths = sorted(
    [os.path.join(input_dir, fname)
for fname in os.listdir(input_dir) if fname.endswith(".jpg")])

# %%
target_paths = sorted(
    [os.path.join(target_dir, fname)
for fname in os.listdir(target_dir)
if fname.endswith(".png") and not fname.startswith(".")])

# %% [markdown]
# # Loading the pre-train SAM Model.

# %%
# ! wget -q https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
CHECKPOINT_PATH='./sam_vit_h_4b8939.pth'

# %%
import torch
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
MODEL_TYPE = "vit_h"

# %%
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor


sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device=DEVICE)


mask_generator = SamAutomaticMaskGenerator(sam)

# %% [markdown]
# ## This function will get the masks from the image using SAM pre-train model

# %%
# Import opencv package
# pip3 install opencv-python
import cv2

def get_mask(image):
    # Convert to RGB format
    
    # Give the path of your image
    IMAGE_PATH= image

    # Read the image from the path
    image= cv2.imread(IMAGE_PATH)

    # Convert to RGB format
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Generate segmentation mask
    output_mask = mask_generator.generate(image_rgb)
    sam_results = output_mask
    print(".",end="")

    return sam_results

# %%
input_img_paths
# Out:
# ['./images/adidas_100.jpg',
#  './images/adidas_101.jpg',
#  './images/adidas_102.jpg',
#  './images/adidas_103.jpg',
#  './images/adidas_104.jpg',
#  './images/adidas_105.jpg',
#  './images/adidas_106.jpg',
#  './images/adidas_107.jpg',
#  './images/adidas_108.jpg',
#  './images/adidas_109.jpg',
#  './images/adidas_110.jpg',
#  './images/adidas_111.jpg',
#  './images/adidas_112.jpg',
#  './images/adidas_113.jpg',
#  './images/adidas_114.jpg',
#  './images/adidas_115.jpg',
#  './images/adidas_116.jpg',
#  './images/adidas_117.jpg',
#  './images/adidas_118.jpg',
#  './images/adidas_119.jpg',
#  './images/adidas_120.jpg',
#  './images/adidas_121.jpg',
#  './images/adidas_122.jpg',
#  './images/adidas_123.jpg',
#  './images/adidas_124.jpg',
#  './images/adidas_125.jpg',
#  './images/adidas_126.jpg',
#  './images/adidas_127.jpg',
#  './images/adidas_128.jpg',
#  './images/adidas_129.jpg',
#  './images/adidas_130.jpg',
#  './images/adidas_131.jpg',
#  './images/adidas_132.jpg',
#  './images/adidas_133.jpg',
#  './images/adidas_134.jpg',
#  './images/adidas_135.jpg',
#  './images/adidas_136.jpg',
#  './images/adidas_137.jpg',
#  './images/adidas_138.jpg',
#  './images/adidas_139.jpg',
#  './images/adidas_140.jpg',
#  './images/adidas_141.jpg',
#  './images/adidas_142.jpg',
#  './images/adidas_143.jpg',
#  './images/adidas_144.jpg',
#  './images/adidas_145.jpg',
#  './images/adidas_146.jpg',
#  './images/adidas_147.jpg',
#  './images/adidas_148.jpg',
#  './images/adidas_149.jpg',
#  './images/adidas_150.jpg',
#  './images/adidas_151.jpg',
#  './images/adidas_152.jpg',
#  './images/adidas_153.jpg',
#  './images/adidas_154.jpg',
#  './images/adidas_155.jpg',
#  './images/adidas_156.jpg',
#  './images/adidas_157.jpg',
#  './images/adidas_158.jpg',
#  './images/adidas_159.jpg',
#  './images/adidas_160.jpg',
#  './images/adidas_161.jpg',
#  './images/adidas_162.jpg',
#  './images/adidas_163.jpg',
#  './images/adidas_164.jpg',
#  './images/adidas_165.jpg',
#  './images/adidas_166.jpg',
#  './images/adidas_167.jpg',
#  './images/adidas_168.jpg',
#  './images/adidas_169.jpg',
#  './images/adidas_170.jpg',
#  './images/adidas_171.jpg',
#  './images/adidas_172.jpg',
#  './images/adidas_173.jpg',
#  './images/adidas_174.jpg',
#  './images/adidas_175.jpg',
#  './images/adidas_176.jpg',
#  './images/adidas_177.jpg',
#  './images/adidas_178.jpg',
#  './images/adidas_179.jpg',
#  './images/adidas_180.jpg',
#  './images/adidas_181.jpg',
#  './images/adidas_182.jpg',
#  './images/adidas_183.jpg',
#  './images/adidas_184.jpg',
#  './images/adidas_185.jpg',
#  './images/adidas_186.jpg',
#  './images/adidas_187.jpg',
#  './images/adidas_188.jpg',
#  './images/adidas_189.jpg',
#  './images/adidas_190.jpg',
#  './images/adidas_191.jpg',
#  './images/adidas_192.jpg',
#  './images/adidas_193.jpg',
#  './images/adidas_194.jpg',
#  './images/adidas_195.jpg',
#  './images/adidas_196.jpg',
#  './images/adidas_197.jpg',
#  './images/adidas_198.jpg',
#  './images/adidas_199.jpg',
#  './images/adidas_200.jpg',
#  './images/adidas_201.jpg',
#  './images/adidas_202.jpg',
#  './images/adidas_203.jpg',
#  './images/adidas_204.jpg',
#  './images/adidas_205.jpg',
#  './images/adidas_206.jpg',
#  './images/adidas_207.jpg',
#  './images/adidas_208.jpg',
#  './images/adidas_209.jpg',
#  './images/adidas_210.jpg',
#  './images/adidas_211.jpg',
#  './images/adidas_212.jpg',
#  './images/adidas_213.jpg',
#  './images/adidas_214.jpg',
#  './images/adidas_215.jpg',
#  './images/adidas_216.jpg',
#  './images/adidas_217.jpg',
#  './images/adidas_218.jpg',
#  './images/adidas_219.jpg',
#  './images/adidas_220.jpg',
#  './images/adidas_221.jpg',
#  './images/adidas_222.jpg',
#  './images/adidas_223.jpg',
#  './images/adidas_224.jpg',
#  './images/adidas_225.jpg',
#  './images/adidas_226.jpg',
#  './images/adidas_227.jpg',
#  './images/adidas_228.jpg',
#  './images/adidas_229.jpg',
#  './images/adidas_230.jpg',
#  './images/adidas_231.jpg',
#  './images/adidas_232.jpg',
#  './images/adidas_233.jpg',
#  './images/adidas_234.jpg',
#  './images/adidas_235.jpg',
#  './images/adidas_236.jpg',
#  './images/adidas_237.jpg',
#  './images/adidas_238.jpg',
#  './images/adidas_239.jpg',
#  './images/adidas_240.jpg',
#  './images/adidas_241.jpg',
#  './images/adidas_242.jpg',
#  './images/adidas_243.jpg',
#  './images/adidas_244.jpg',
#  './images/adidas_245.jpg',
#  './images/adidas_246.jpg',
#  './images/adidas_247.jpg',
#  './images/adidas_248.jpg',
#  './images/adidas_249.jpg',
#  './images/adidas_250.jpg',
#  './images/adidas_251.jpg',
#  './images/adidas_252.jpg',
#  './images/adidas_253.jpg',
#  './images/adidas_254.jpg',
#  './images/adidas_255.jpg',
#  './images/adidas_256.jpg',
#  './images/adidas_257.jpg',
#  './images/adidas_258.jpg',
#  './images/adidas_259.jpg',
#  './images/adidas_260.jpg',
#  './images/adidas_261.jpg',
#  './images/adidas_262.jpg',
#  './images/adidas_263.jpg',
#  './images/adidas_264.jpg',
#  './images/adidas_265.jpg',
#  './images/adidas_266.jpg',
#  './images/adidas_267.jpg',
#  './images/adidas_268.jpg',
#  './images/adidas_269.jpg',
#  './images/adidas_270.jpg',
#  './images/adidas_271.jpg',
#  './images/adidas_272.jpg',
#  './images/adidas_273.jpg',
#  './images/adidas_274.jpg',
#  './images/adidas_38.jpg',
#  './images/adidas_39.jpg',
#  './images/adidas_40.jpg',
#  './images/adidas_41.jpg',
#  './images/adidas_42.jpg',
#  './images/adidas_43.jpg',
#  './images/adidas_44.jpg',
#  './images/adidas_45.jpg',
#  './images/adidas_46.jpg',
#  './images/adidas_47.jpg',
#  './images/adidas_48.jpg',
#  './images/adidas_49.jpg',
#  './images/adidas_50.jpg',
#  './images/adidas_51.jpg',
#  './images/adidas_52.jpg',
#  './images/adidas_53.jpg',
#  './images/adidas_54.jpg',
#  './images/adidas_55.jpg',
#  './images/adidas_56.jpg',
#  './images/adidas_57.jpg',
#  './images/adidas_58.jpg',
#  './images/adidas_59.jpg',
#  './images/adidas_60.jpg',
#  './images/adidas_61.jpg',
#  './images/adidas_62.jpg',
#  './images/adidas_63.jpg',
#  './images/adidas_64.jpg',
#  './images/adidas_65.jpg',
#  './images/adidas_66.jpg',
#  './images/adidas_67.jpg',
#  './images/adidas_68.jpg',
#  './images/adidas_69.jpg',
#  './images/adidas_70.jpg',
#  './images/adidas_71.jpg',
#  './images/adidas_72.jpg',
#  './images/adidas_73.jpg',
#  './images/adidas_74.jpg',
#  './images/adidas_75.jpg',
#  './images/adidas_76.jpg',
#  './images/adidas_77.jpg',
#  './images/adidas_78.jpg',
#  './images/adidas_79.jpg',
#  './images/adidas_80.jpg',
#  './images/adidas_81.jpg',
#  './images/adidas_82.jpg',
#  './images/adidas_83.jpg',
#  './images/adidas_84.jpg',
#  './images/adidas_85.jpg',
#  './images/adidas_86.jpg',
#  './images/adidas_87.jpg',
#  './images/adidas_88.jpg',
#  './images/adidas_89.jpg',
#  './images/adidas_90.jpg',
#  './images/adidas_91.jpg',
#  './images/adidas_92.jpg',
#  './images/adidas_93.jpg',
#  './images/adidas_94.jpg',
#  './images/adidas_95.jpg',
#  './images/adidas_96.jpg',
#  './images/adidas_97.jpg',
#  './images/adidas_98.jpg',
#  './images/adidas_99.jpg',
#  './images/converse_100.jpg',
#  './images/converse_101.jpg',
#  './images/converse_102.jpg',
#  './images/converse_103.jpg',
#  './images/converse_104.jpg',
#  './images/converse_105.jpg',
#  './images/converse_106.jpg',
#  './images/converse_107.jpg',
#  './images/converse_108.jpg',
#  './images/converse_109.jpg',
#  './images/converse_110.jpg',
#  './images/converse_111.jpg',
#  './images/converse_112.jpg',
#  './images/converse_113.jpg',
#  './images/converse_114.jpg',
#  './images/converse_115.jpg',
#  './images/converse_116.jpg',
#  './images/converse_117.jpg',
#  './images/converse_118.jpg',
#  './images/converse_119.jpg',
#  './images/converse_120.jpg',
#  './images/converse_121.jpg',
#  './images/converse_122.jpg',
#  './images/converse_123.jpg',
#  './images/converse_124.jpg',
#  './images/converse_125.jpg',
#  './images/converse_126.jpg',
#  './images/converse_127.jpg',
#  './images/converse_128.jpg',
#  './images/converse_129.jpg',
#  './images/converse_130.jpg',
#  './images/converse_131.jpg',
#  './images/converse_132.jpg',
#  './images/converse_133.jpg',
#  './images/converse_134.jpg',
#  './images/converse_135.jpg',
#  './images/converse_136.jpg',
#  './images/converse_137.jpg',
#  './images/converse_138.jpg',
#  './images/converse_139.jpg',
#  './images/converse_140.jpg',
#  './images/converse_141.jpg',
#  './images/converse_142.jpg',
#  './images/converse_143.jpg',
#  './images/converse_144.jpg',
#  './images/converse_145.jpg',
#  './images/converse_146.jpg',
#  './images/converse_147.jpg',
#  './images/converse_148.jpg',
#  './images/converse_149.jpg',
#  './images/converse_150.jpg',
#  './images/converse_151.jpg',
#  './images/converse_152.jpg',
#  './images/converse_153.jpg',
#  './images/converse_154.jpg',
#  './images/converse_155.jpg',
#  './images/converse_156.jpg',
#  './images/converse_157.jpg',
#  './images/converse_158.jpg',
#  './images/converse_159.jpg',
#  './images/converse_160.jpg',
#  './images/converse_161.jpg',
#  './images/converse_162.jpg',
#  './images/converse_163.jpg',
#  './images/converse_164.jpg',
#  './images/converse_165.jpg',
#  './images/converse_166.jpg',
#  './images/converse_167.jpg',
#  './images/converse_168.jpg',
#  './images/converse_169.jpg',
#  './images/converse_170.jpg',
#  './images/converse_171.jpg',
#  './images/converse_172.jpg',
#  './images/converse_173.jpg',
#  './images/converse_174.jpg',
#  './images/converse_175.jpg',
#  './images/converse_176.jpg',
#  './images/converse_177.jpg',
#  './images/converse_178.jpg',
#  './images/converse_179.jpg',
#  './images/converse_180.jpg',
#  './images/converse_181.jpg',
#  './images/converse_182.jpg',
#  './images/converse_183.jpg',
#  './images/converse_184.jpg',
#  './images/converse_185.jpg',
#  './images/converse_186.jpg',
#  './images/converse_187.jpg',
#  './images/converse_188.jpg',
#  './images/converse_189.jpg',
#  './images/converse_190.jpg',
#  './images/converse_191.jpg',
#  './images/converse_192.jpg',
#  './images/converse_193.jpg',
#  './images/converse_194.jpg',
#  './images/converse_195.jpg',
#  './images/converse_196.jpg',
#  './images/converse_197.jpg',
#  './images/converse_198.jpg',
#  './images/converse_199.jpg',
#  './images/converse_200.jpg',
#  './images/converse_201.jpg',
#  './images/converse_202.jpg',
#  './images/converse_203.jpg',
#  './images/converse_204.jpg',
#  './images/converse_205.jpg',
#  './images/converse_206.jpg',
#  './images/converse_207.jpg',
#  './images/converse_208.jpg',
#  './images/converse_209.jpg',
#  './images/converse_210.jpg',
#  './images/converse_211.jpg',
#  './images/converse_212.jpg',
#  './images/converse_213.jpg',
#  './images/converse_214.jpg',
#  './images/converse_215.jpg',
#  './images/converse_216.jpg',
#  './images/converse_217.jpg',
#  './images/converse_218.jpg',
#  './images/converse_219.jpg',
#  './images/converse_220.jpg',
#  './images/converse_221.jpg',
#  './images/converse_222.jpg',
#  './images/converse_223.jpg',
#  './images/converse_224.jpg',
#  './images/converse_225.jpg',
#  './images/converse_226.jpg',
#  './images/converse_227.jpg',
#  './images/converse_228.jpg',
#  './images/converse_229.jpg',
#  './images/converse_230.jpg',
#  './images/converse_231.jpg',
#  './images/converse_232.jpg',
#  './images/converse_233.jpg',
#  './images/converse_234.jpg',
#  './images/converse_235.jpg',
#  './images/converse_236.jpg',
#  './images/converse_237.jpg',
#  './images/converse_238.jpg',
#  './images/converse_239.jpg',
#  './images/converse_240.jpg',
#  './images/converse_241.jpg',
#  './images/converse_242.jpg',
#  './images/converse_243.jpg',
#  './images/converse_244.jpg',
#  './images/converse_245.jpg',
#  './images/converse_246.jpg',
#  './images/converse_247.jpg',
#  './images/converse_248.jpg',
#  './images/converse_249.jpg',
#  './images/converse_250.jpg',
#  './images/converse_251.jpg',
#  './images/converse_252.jpg',
#  './images/converse_253.jpg',
#  './images/converse_254.jpg',
#  './images/converse_255.jpg',
#  './images/converse_256.jpg',
#  './images/converse_257.jpg',
#  './images/converse_258.jpg',
#  './images/converse_259.jpg',
#  './images/converse_260.jpg',
#  './images/converse_261.jpg',
#  './images/converse_262.jpg',
#  './images/converse_263.jpg',
#  './images/converse_264.jpg',
#  './images/converse_265.jpg',
#  './images/converse_266.jpg',
#  './images/converse_267.jpg',
#  './images/converse_268.jpg',
#  './images/converse_269.jpg',
#  './images/converse_270.jpg',
#  './images/converse_271.jpg',
#  './images/converse_272.jpg',
#  './images/converse_273.jpg',
#  './images/converse_274.jpg',
#  './images/converse_38.jpg',
#  './images/converse_39.jpg',
#  './images/converse_40.jpg',
#  './images/converse_41.jpg',
#  './images/converse_42.jpg',
#  './images/converse_43.jpg',
#  './images/converse_44.jpg',
#  './images/converse_45.jpg',
#  './images/converse_46.jpg',
#  './images/converse_47.jpg',
#  './images/converse_48.jpg',
#  './images/converse_49.jpg',
#  './images/converse_50.jpg',
#  './images/converse_51.jpg',
#  './images/converse_52.jpg',
#  './images/converse_53.jpg',
#  './images/converse_54.jpg',
#  './images/converse_55.jpg',
#  './images/converse_56.jpg',
#  './images/converse_57.jpg',
#  './images/converse_58.jpg',
#  './images/converse_59.jpg',
#  './images/converse_60.jpg',
#  './images/converse_61.jpg',
#  './images/converse_62.jpg',
#  './images/converse_63.jpg',
#  './images/converse_64.jpg',
#  './images/converse_65.jpg',
#  './images/converse_66.jpg',
#  './images/converse_67.jpg',
#  './images/converse_68.jpg',
#  './images/converse_69.jpg',
#  './images/converse_70.jpg',
#  './images/converse_71.jpg',
#  './images/converse_72.jpg',
#  './images/converse_73.jpg',
#  './images/converse_74.jpg',
#  './images/converse_75.jpg',
#  './images/converse_76.jpg',
#  './images/converse_77.jpg',
#  './images/converse_78.jpg',
#  './images/converse_79.jpg',
#  './images/converse_80.jpg',
#  './images/converse_81.jpg',
#  './images/converse_82.jpg',
#  './images/converse_83.jpg',
#  './images/converse_84.jpg',
#  './images/converse_85.jpg',
#  './images/converse_86.jpg',
#  './images/converse_87.jpg',
#  './images/converse_88.jpg',
#  './images/converse_89.jpg',
#  './images/converse_90.jpg',
#  './images/converse_91.jpg',
#  './images/converse_92.jpg',
#  './images/converse_93.jpg',
#  './images/converse_94.jpg',
#  './images/converse_95.jpg',
#  './images/converse_96.jpg',
#  './images/converse_97.jpg',
#  './images/converse_98.jpg',
#  './images/converse_99.jpg',
#  './images/nike_100.jpg',
#  './images/nike_101.jpg',
#  './images/nike_102.jpg',
#  './images/nike_103.jpg',
#  './images/nike_104.jpg',
#  './images/nike_105.jpg',
#  './images/nike_106.jpg',
#  './images/nike_107.jpg',
#  './images/nike_108.jpg',
#  './images/nike_109.jpg',
#  './images/nike_110.jpg',
#  './images/nike_111.jpg',
#  './images/nike_112.jpg',
#  './images/nike_113.jpg',
#  './images/nike_114.jpg',
#  './images/nike_115.jpg',
#  './images/nike_116.jpg',
#  './images/nike_117.jpg',
#  './images/nike_118.jpg',
#  './images/nike_119.jpg',
#  './images/nike_120.jpg',
#  './images/nike_121.jpg',
#  './images/nike_122.jpg',
#  './images/nike_123.jpg',
#  './images/nike_124.jpg',
#  './images/nike_125.jpg',
#  './images/nike_126.jpg',
#  './images/nike_127.jpg',
#  './images/nike_128.jpg',
#  './images/nike_129.jpg',
#  './images/nike_130.jpg',
#  './images/nike_131.jpg',
#  './images/nike_132.jpg',
#  './images/nike_133.jpg',
#  './images/nike_134.jpg',
#  './images/nike_135.jpg',
#  './images/nike_136.jpg',
#  './images/nike_137.jpg',
#  './images/nike_138.jpg',
#  './images/nike_139.jpg',
#  './images/nike_140.jpg',
#  './images/nike_141.jpg',
#  './images/nike_142.jpg',
#  './images/nike_143.jpg',
#  './images/nike_144.jpg',
#  './images/nike_145.jpg',
#  './images/nike_146.jpg',
#  './images/nike_147.jpg',
#  './images/nike_148.jpg',
#  './images/nike_149.jpg',
#  './images/nike_150.jpg',
#  './images/nike_151.jpg',
#  './images/nike_152.jpg',
#  './images/nike_153.jpg',
#  './images/nike_154.jpg',
#  './images/nike_155.jpg',
#  './images/nike_156.jpg',
#  './images/nike_157.jpg',
#  './images/nike_158.jpg',
#  './images/nike_159.jpg',
#  './images/nike_160.jpg',
#  './images/nike_161.jpg',
#  './images/nike_162.jpg',
#  './images/nike_163.jpg',
#  './images/nike_164.jpg',
#  './images/nike_165.jpg',
#  './images/nike_166.jpg',
#  './images/nike_167.jpg',
#  './images/nike_168.jpg',
#  './images/nike_169.jpg',
#  './images/nike_170.jpg',
#  './images/nike_171.jpg',
#  './images/nike_172.jpg',
#  './images/nike_173.jpg',
#  './images/nike_174.jpg',
#  './images/nike_175.jpg',
#  './images/nike_176.jpg',
#  './images/nike_177.jpg',
#  './images/nike_178.jpg',
#  './images/nike_179.jpg',
#  './images/nike_180.jpg',
#  './images/nike_181.jpg',
#  './images/nike_182.jpg',
#  './images/nike_183.jpg',
#  './images/nike_184.jpg',
#  './images/nike_185.jpg',
#  './images/nike_186.jpg',
#  './images/nike_187.jpg',
#  './images/nike_188.jpg',
#  './images/nike_189.jpg',
#  './images/nike_190.jpg',
#  './images/nike_191.jpg',
#  './images/nike_192.jpg',
#  './images/nike_193.jpg',
#  './images/nike_194.jpg',
#  './images/nike_195.jpg',
#  './images/nike_196.jpg',
#  './images/nike_197.jpg',
#  './images/nike_198.jpg',
#  './images/nike_199.jpg',
#  './images/nike_200.jpg',
#  './images/nike_201.jpg',
#  './images/nike_202.jpg',
#  './images/nike_203.jpg',
#  './images/nike_204.jpg',
#  './images/nike_205.jpg',
#  './images/nike_206.jpg',
#  './images/nike_207.jpg',
#  './images/nike_208.jpg',
#  './images/nike_209.jpg',
#  './images/nike_210.jpg',
#  './images/nike_211.jpg',
#  './images/nike_212.jpg',
#  './images/nike_213.jpg',
#  './images/nike_214.jpg',
#  './images/nike_215.jpg',
#  './images/nike_216.jpg',
#  './images/nike_217.jpg',
#  './images/nike_218.jpg',
#  './images/nike_219.jpg',
#  './images/nike_220.jpg',
#  './images/nike_221.jpg',
#  './images/nike_222.jpg',
#  './images/nike_223.jpg',
#  './images/nike_224.jpg',
#  './images/nike_225.jpg',
#  './images/nike_226.jpg',
#  './images/nike_227.jpg',
#  './images/nike_228.jpg',
#  './images/nike_229.jpg',
#  './images/nike_230.jpg',
#  './images/nike_231.jpg',
#  './images/nike_232.jpg',
#  './images/nike_233.jpg',
#  './images/nike_234.jpg',
#  './images/nike_235.jpg',
#  './images/nike_236.jpg',
#  './images/nike_237.jpg',
#  './images/nike_238.jpg',
#  './images/nike_239.jpg',
#  './images/nike_240.jpg',
#  './images/nike_241.jpg',
#  './images/nike_242.jpg',
#  './images/nike_243.jpg',
#  './images/nike_244.jpg',
#  './images/nike_245.jpg',
#  './images/nike_246.jpg',
#  './images/nike_247.jpg',
#  './images/nike_248.jpg',
#  './images/nike_249.jpg',
#  './images/nike_250.jpg',
#  './images/nike_251.jpg',
#  './images/nike_252.jpg',
#  './images/nike_253.jpg',
#  './images/nike_254.jpg',
#  './images/nike_255.jpg',
#  './images/nike_256.jpg',
#  './images/nike_257.jpg',
#  './images/nike_258.jpg',
#  './images/nike_259.jpg',
#  './images/nike_260.jpg',
#  './images/nike_261.jpg',
#  './images/nike_262.jpg',
#  './images/nike_263.jpg',
#  './images/nike_264.jpg',
#  './images/nike_265.jpg',
#  './images/nike_266.jpg',
#  './images/nike_267.jpg',
#  './images/nike_268.jpg',
#  './images/nike_269.jpg',
#  './images/nike_270.jpg',
#  './images/nike_271.jpg',
#  './images/nike_272.jpg',
#  './images/nike_273.jpg',
#  './images/nike_274.jpg',
#  './images/nike_38.jpg',
#  './images/nike_39.jpg',
#  './images/nike_40.jpg',
#  './images/nike_41.jpg',
#  './images/nike_42.jpg',
#  './images/nike_43.jpg',
#  './images/nike_44.jpg',
#  './images/nike_45.jpg',
#  './images/nike_46.jpg',
#  './images/nike_47.jpg',
#  './images/nike_48.jpg',
#  './images/nike_49.jpg',
#  './images/nike_50.jpg',
#  './images/nike_51.jpg',
#  './images/nike_52.jpg',
#  './images/nike_53.jpg',
#  './images/nike_54.jpg',
#  './images/nike_55.jpg',
#  './images/nike_56.jpg',
#  './images/nike_57.jpg',
#  './images/nike_58.jpg',
#  './images/nike_59.jpg',
#  './images/nike_60.jpg',
#  './images/nike_61.jpg',
#  './images/nike_62.jpg',
#  './images/nike_63.jpg',
#  './images/nike_64.jpg',
#  './images/nike_65.jpg',
#  './images/nike_66.jpg',
#  './images/nike_67.jpg',
#  './images/nike_68.jpg',
#  './images/nike_69.jpg',
#  './images/nike_70.jpg',
#  './images/nike_71.jpg',
#  './images/nike_72.jpg',
#  './images/nike_73.jpg',
#  './images/nike_74.jpg',
#  './images/nike_75.jpg',
#  './images/nike_76.jpg',
#  './images/nike_77.jpg',
#  './images/nike_78.jpg',
#  './images/nike_79.jpg',
#  './images/nike_80.jpg',
#  './images/nike_81.jpg',
#  './images/nike_82.jpg',
#  './images/nike_83.jpg',
#  './images/nike_84.jpg',
#  './images/nike_85.jpg',
#  './images/nike_86.jpg',
#  './images/nike_87.jpg',
#  './images/nike_88.jpg',
#  './images/nike_89.jpg',
#  './images/nike_90.jpg',
#  './images/nike_91.jpg',
#  './images/nike_92.jpg',
#  './images/nike_93.jpg',
#  './images/nike_94.jpg',
#  './images/nike_95.jpg',
#  './images/nike_96.jpg',
#  './images/nike_97.jpg',
#  './images/nike_98.jpg',
#  './images/nike_99.jpg']

# %% [markdown]
# ## Adding the correct directory and extnesion file for the mask.

# %%
target_dir+input_img_paths[0].split("/")[-1].split(".")[0]+".png"
# Out:
# './annotations/trimaps/adidas_100.png'

# %%
target_paths
# Out:
# []

# %% [markdown]
# # Finding the Best Image Mask

# %%
def find_the_best_mask(sam_results):
    a = []
    for val in sam_results:
        #print((val['predicted_iou']))
        a.append(val['predicted_iou'])
    ar = np.array(a)
    mask = sam_results[np.argmax(ar)]['segmentation']
    return mask

# %% [markdown]
# ## Saving The Mask
#
# This Function gets the best mask, then builds the contour aorund the mask wiht the correct label, change the original mask from boolean to numeric, changes the background and finally saves it wiht the correct format.

# %%
def save_the_mask(mask, image_name):
    #target_dir
    # Change from Bool to uint8
    new_mask = mask.astype(np.uint8)
    
    # Put a Contour on the row side
    print("R",end='')
    for row in range(0, new_mask.shape[0]):
        #print("R",end='')
        for col in range(0, new_mask.shape[1]-1):
            #print(new_mask[row,col],end='')
            #print(previous_pixel)
            if col != new_mask.shape[1]-1:
                next_pixel = new_mask[row,col+1]
            #print(" n:",row,",",col+1," ",next_pixel)
            #print("[",new_mask[row,col],"-",next_pixel,"]",end='')
            if (new_mask[row,col] == 0) & (next_pixel == 1):
                new_mask[row,col] = 3
                #print("change")
            if (new_mask[row,col] == 1) & (next_pixel == 0):
                #print("change")
                new_mask[row,col+1] = 3

    # put a contour on the column side
    print("C",end='')
    for col in range(0, new_mask.shape[1]):
        #print("C",end='')
        for row in range(0, new_mask.shape[0]-1):
            #print(new_mask[row,col],end='')
            #print(previous_pixel)
            if row != new_mask.shape[0]-1:
                next_pixel = new_mask[row+1,col]
            #print(" n:",row,",",col+1," ",next_pixel)
            #print("[",new_mask[row,col],"-",next_pixel,"]",end='')
            if (new_mask[row,col] == 0) & ((next_pixel == 4) | (next_pixel == 1)):
                new_mask[row,col] = 3
                #print("change")
            if ((new_mask[row,col] == 4) | (new_mask[row,col] == 1)) & (next_pixel == 0):
                #print("change")
                new_mask[row+1,col] = 3
    
    # we need to change the backgrond from 0 to 2
    print("B",end='')
    for row in range(0, new_mask.shape[0]):
        for col in range(0, new_mask.shape[1]):
            if (new_mask[row,col] == 0):
                new_mask[row,col] = 2
        
    mask_image = (new_mask).astype(np.uint8)  # Convert to uint8 format

    # Save the mask image
    print("S",end='')
    png_mask = target_dir+image_name.split("/")[-1].split(".")[0]+".png"
    cv2.imwrite(png_mask, mask_image)
    return png_mask, mask_image

# %% [markdown]
# ## This fucion is only for humans to see the mask image as the mask only has values of 1,2 and 3. if we do not normalize it, it is just a black image.

# %%
def display_target(target_array):
    normalized_array = (target_array.astype("uint8") - 1) * 127 
    plt.axis("off")
    plt.imshow(normalized_array[:, :])
    plt.show()

#img = img_to_array(load_img(target_paths[0], color_mode="grayscale"))
#display_target(new_mask)

# %% [markdown]
# ## This funcion will take all the images one by one and return the mask image and save the files.

# %%
total_images = len(input_img_paths)
for i in range(len(input_img_paths)):
    print("processin image ",i," of ",total_images)
    print(f"Processing image {input_img_paths[i]}")
    sam_results = get_mask(input_img_paths[i])
    mask = find_the_best_mask(sam_results)
    png_mask, final_mask = save_the_mask(mask, input_img_paths[i])
    #display_target(final_mask)
    print(f"Saved mask {png_mask}")
# Out:
# processin image  0  of  711
# Processing image ./images/adidas_100.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_100.png
# processin image  1  of  711
# Processing image ./images/adidas_101.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_101.png
# processin image  2  of  711
# Processing image ./images/adidas_102.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_102.png
# processin image  3  of  711
# Processing image ./images/adidas_103.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_103.png
# processin image  4  of  711
# Processing image ./images/adidas_104.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_104.png
# processin image  5  of  711
# Processing image ./images/adidas_105.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_105.png
# processin image  6  of  711
# Processing image ./images/adidas_106.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_106.png
# processin image  7  of  711
# Processing image ./images/adidas_107.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_107.png
# processin image  8  of  711
# Processing image ./images/adidas_108.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_108.png
# processin image  9  of  711
# Processing image ./images/adidas_109.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_109.png
# processin image  10  of  711
# Processing image ./images/adidas_110.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_110.png
# processin image  11  of  711
# Processing image ./images/adidas_111.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_111.png
# processin image  12  of  711
# Processing image ./images/adidas_112.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_112.png
# processin image  13  of  711
# Processing image ./images/adidas_113.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_113.png
# processin image  14  of  711
# Processing image ./images/adidas_114.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_114.png
# processin image  15  of  711
# Processing image ./images/adidas_115.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_115.png
# processin image  16  of  711
# Processing image ./images/adidas_116.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_116.png
# processin image  17  of  711
# Processing image ./images/adidas_117.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_117.png
# processin image  18  of  711
# Processing image ./images/adidas_118.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_118.png
# processin image  19  of  711
# Processing image ./images/adidas_119.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_119.png
# processin image  20  of  711
# Processing image ./images/adidas_120.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_120.png
# processin image  21  of  711
# Processing image ./images/adidas_121.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_121.png
# processin image  22  of  711
# Processing image ./images/adidas_122.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_122.png
# processin image  23  of  711
# Processing image ./images/adidas_123.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_123.png
# processin image  24  of  711
# Processing image ./images/adidas_124.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_124.png
# processin image  25  of  711
# Processing image ./images/adidas_125.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_125.png
# processin image  26  of  711
# Processing image ./images/adidas_126.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_126.png
# processin image  27  of  711
# Processing image ./images/adidas_127.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_127.png
# processin image  28  of  711
# Processing image ./images/adidas_128.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_128.png
# processin image  29  of  711
# Processing image ./images/adidas_129.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_129.png
# processin image  30  of  711
# Processing image ./images/adidas_130.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_130.png
# processin image  31  of  711
# Processing image ./images/adidas_131.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_131.png
# processin image  32  of  711
# Processing image ./images/adidas_132.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_132.png
# processin image  33  of  711
# Processing image ./images/adidas_133.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_133.png
# processin image  34  of  711
# Processing image ./images/adidas_134.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_134.png
# processin image  35  of  711
# Processing image ./images/adidas_135.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_135.png
# processin image  36  of  711
# Processing image ./images/adidas_136.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_136.png
# processin image  37  of  711
# Processing image ./images/adidas_137.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_137.png
# processin image  38  of  711
# Processing image ./images/adidas_138.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_138.png
# processin image  39  of  711
# Processing image ./images/adidas_139.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_139.png
# processin image  40  of  711
# Processing image ./images/adidas_140.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_140.png
# processin image  41  of  711
# Processing image ./images/adidas_141.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_141.png
# processin image  42  of  711
# Processing image ./images/adidas_142.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_142.png
# processin image  43  of  711
# Processing image ./images/adidas_143.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_143.png
# processin image  44  of  711
# Processing image ./images/adidas_144.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_144.png
# processin image  45  of  711
# Processing image ./images/adidas_145.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_145.png
# processin image  46  of  711
# Processing image ./images/adidas_146.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_146.png
# processin image  47  of  711
# Processing image ./images/adidas_147.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_147.png
# processin image  48  of  711
# Processing image ./images/adidas_148.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_148.png
# processin image  49  of  711
# Processing image ./images/adidas_149.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_149.png
# processin image  50  of  711
# Processing image ./images/adidas_150.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_150.png
# processin image  51  of  711
# Processing image ./images/adidas_151.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_151.png
# processin image  52  of  711
# Processing image ./images/adidas_152.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_152.png
# processin image  53  of  711
# Processing image ./images/adidas_153.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_153.png
# processin image  54  of  711
# Processing image ./images/adidas_154.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_154.png
# processin image  55  of  711
# Processing image ./images/adidas_155.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_155.png
# processin image  56  of  711
# Processing image ./images/adidas_156.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_156.png
# processin image  57  of  711
# Processing image ./images/adidas_157.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_157.png
# processin image  58  of  711
# Processing image ./images/adidas_158.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_158.png
# processin image  59  of  711
# Processing image ./images/adidas_159.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_159.png
# processin image  60  of  711
# Processing image ./images/adidas_160.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_160.png
# processin image  61  of  711
# Processing image ./images/adidas_161.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_161.png
# processin image  62  of  711
# Processing image ./images/adidas_162.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_162.png
# processin image  63  of  711
# Processing image ./images/adidas_163.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_163.png
# processin image  64  of  711
# Processing image ./images/adidas_164.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_164.png
# processin image  65  of  711
# Processing image ./images/adidas_165.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_165.png
# processin image  66  of  711
# Processing image ./images/adidas_166.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_166.png
# processin image  67  of  711
# Processing image ./images/adidas_167.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_167.png
# processin image  68  of  711
# Processing image ./images/adidas_168.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_168.png
# processin image  69  of  711
# Processing image ./images/adidas_169.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_169.png
# processin image  70  of  711
# Processing image ./images/adidas_170.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_170.png
# processin image  71  of  711
# Processing image ./images/adidas_171.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_171.png
# processin image  72  of  711
# Processing image ./images/adidas_172.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_172.png
# processin image  73  of  711
# Processing image ./images/adidas_173.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_173.png
# processin image  74  of  711
# Processing image ./images/adidas_174.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_174.png
# processin image  75  of  711
# Processing image ./images/adidas_175.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_175.png
# processin image  76  of  711
# Processing image ./images/adidas_176.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_176.png
# processin image  77  of  711
# Processing image ./images/adidas_177.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_177.png
# processin image  78  of  711
# Processing image ./images/adidas_178.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_178.png
# processin image  79  of  711
# Processing image ./images/adidas_179.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_179.png
# processin image  80  of  711
# Processing image ./images/adidas_180.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_180.png
# processin image  81  of  711
# Processing image ./images/adidas_181.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_181.png
# processin image  82  of  711
# Processing image ./images/adidas_182.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_182.png
# processin image  83  of  711
# Processing image ./images/adidas_183.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_183.png
# processin image  84  of  711
# Processing image ./images/adidas_184.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_184.png
# processin image  85  of  711
# Processing image ./images/adidas_185.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_185.png
# processin image  86  of  711
# Processing image ./images/adidas_186.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_186.png
# processin image  87  of  711
# Processing image ./images/adidas_187.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_187.png
# processin image  88  of  711
# Processing image ./images/adidas_188.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_188.png
# processin image  89  of  711
# Processing image ./images/adidas_189.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_189.png
# processin image  90  of  711
# Processing image ./images/adidas_190.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_190.png
# processin image  91  of  711
# Processing image ./images/adidas_191.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_191.png
# processin image  92  of  711
# Processing image ./images/adidas_192.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_192.png
# processin image  93  of  711
# Processing image ./images/adidas_193.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_193.png
# processin image  94  of  711
# Processing image ./images/adidas_194.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_194.png
# processin image  95  of  711
# Processing image ./images/adidas_195.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_195.png
# processin image  96  of  711
# Processing image ./images/adidas_196.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_196.png
# processin image  97  of  711
# Processing image ./images/adidas_197.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_197.png
# processin image  98  of  711
# Processing image ./images/adidas_198.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_198.png
# processin image  99  of  711
# Processing image ./images/adidas_199.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_199.png
# processin image  100  of  711
# Processing image ./images/adidas_200.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_200.png
# processin image  101  of  711
# Processing image ./images/adidas_201.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_201.png
# processin image  102  of  711
# Processing image ./images/adidas_202.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_202.png
# processin image  103  of  711
# Processing image ./images/adidas_203.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_203.png
# processin image  104  of  711
# Processing image ./images/adidas_204.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_204.png
# processin image  105  of  711
# Processing image ./images/adidas_205.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_205.png
# processin image  106  of  711
# Processing image ./images/adidas_206.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_206.png
# processin image  107  of  711
# Processing image ./images/adidas_207.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_207.png
# processin image  108  of  711
# Processing image ./images/adidas_208.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_208.png
# processin image  109  of  711
# Processing image ./images/adidas_209.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_209.png
# processin image  110  of  711
# Processing image ./images/adidas_210.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_210.png
# processin image  111  of  711
# Processing image ./images/adidas_211.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_211.png
# processin image  112  of  711
# Processing image ./images/adidas_212.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_212.png
# processin image  113  of  711
# Processing image ./images/adidas_213.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_213.png
# processin image  114  of  711
# Processing image ./images/adidas_214.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_214.png
# processin image  115  of  711
# Processing image ./images/adidas_215.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_215.png
# processin image  116  of  711
# Processing image ./images/adidas_216.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_216.png
# processin image  117  of  711
# Processing image ./images/adidas_217.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_217.png
# processin image  118  of  711
# Processing image ./images/adidas_218.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_218.png
# processin image  119  of  711
# Processing image ./images/adidas_219.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_219.png
# processin image  120  of  711
# Processing image ./images/adidas_220.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_220.png
# processin image  121  of  711
# Processing image ./images/adidas_221.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_221.png
# processin image  122  of  711
# Processing image ./images/adidas_222.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_222.png
# processin image  123  of  711
# Processing image ./images/adidas_223.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_223.png
# processin image  124  of  711
# Processing image ./images/adidas_224.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_224.png
# processin image  125  of  711
# Processing image ./images/adidas_225.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_225.png
# processin image  126  of  711
# Processing image ./images/adidas_226.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_226.png
# processin image  127  of  711
# Processing image ./images/adidas_227.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_227.png
# processin image  128  of  711
# Processing image ./images/adidas_228.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_228.png
# processin image  129  of  711
# Processing image ./images/adidas_229.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_229.png
# processin image  130  of  711
# Processing image ./images/adidas_230.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_230.png
# processin image  131  of  711
# Processing image ./images/adidas_231.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_231.png
# processin image  132  of  711
# Processing image ./images/adidas_232.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_232.png
# processin image  133  of  711
# Processing image ./images/adidas_233.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_233.png
# processin image  134  of  711
# Processing image ./images/adidas_234.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_234.png
# processin image  135  of  711
# Processing image ./images/adidas_235.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_235.png
# processin image  136  of  711
# Processing image ./images/adidas_236.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_236.png
# processin image  137  of  711
# Processing image ./images/adidas_237.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_237.png
# processin image  138  of  711
# Processing image ./images/adidas_238.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_238.png
# processin image  139  of  711
# Processing image ./images/adidas_239.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_239.png
# processin image  140  of  711
# Processing image ./images/adidas_240.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_240.png
# processin image  141  of  711
# Processing image ./images/adidas_241.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_241.png
# processin image  142  of  711
# Processing image ./images/adidas_242.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_242.png
# processin image  143  of  711
# Processing image ./images/adidas_243.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_243.png
# processin image  144  of  711
# Processing image ./images/adidas_244.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_244.png
# processin image  145  of  711
# Processing image ./images/adidas_245.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_245.png
# processin image  146  of  711
# Processing image ./images/adidas_246.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_246.png
# processin image  147  of  711
# Processing image ./images/adidas_247.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_247.png
# processin image  148  of  711
# Processing image ./images/adidas_248.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_248.png
# processin image  149  of  711
# Processing image ./images/adidas_249.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_249.png
# processin image  150  of  711
# Processing image ./images/adidas_250.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_250.png
# processin image  151  of  711
# Processing image ./images/adidas_251.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_251.png
# processin image  152  of  711
# Processing image ./images/adidas_252.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_252.png
# processin image  153  of  711
# Processing image ./images/adidas_253.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_253.png
# processin image  154  of  711
# Processing image ./images/adidas_254.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_254.png
# processin image  155  of  711
# Processing image ./images/adidas_255.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_255.png
# processin image  156  of  711
# Processing image ./images/adidas_256.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_256.png
# processin image  157  of  711
# Processing image ./images/adidas_257.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_257.png
# processin image  158  of  711
# Processing image ./images/adidas_258.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_258.png
# processin image  159  of  711
# Processing image ./images/adidas_259.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_259.png
# processin image  160  of  711
# Processing image ./images/adidas_260.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_260.png
# processin image  161  of  711
# Processing image ./images/adidas_261.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_261.png
# processin image  162  of  711
# Processing image ./images/adidas_262.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_262.png
# processin image  163  of  711
# Processing image ./images/adidas_263.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_263.png
# processin image  164  of  711
# Processing image ./images/adidas_264.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_264.png
# processin image  165  of  711
# Processing image ./images/adidas_265.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_265.png
# processin image  166  of  711
# Processing image ./images/adidas_266.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_266.png
# processin image  167  of  711
# Processing image ./images/adidas_267.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_267.png
# processin image  168  of  711
# Processing image ./images/adidas_268.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_268.png
# processin image  169  of  711
# Processing image ./images/adidas_269.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_269.png
# processin image  170  of  711
# Processing image ./images/adidas_270.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_270.png
# processin image  171  of  711
# Processing image ./images/adidas_271.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_271.png
# processin image  172  of  711
# Processing image ./images/adidas_272.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_272.png
# processin image  173  of  711
# Processing image ./images/adidas_273.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_273.png
# processin image  174  of  711
# Processing image ./images/adidas_274.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_274.png
# processin image  175  of  711
# Processing image ./images/adidas_38.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_38.png
# processin image  176  of  711
# Processing image ./images/adidas_39.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_39.png
# processin image  177  of  711
# Processing image ./images/adidas_40.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_40.png
# processin image  178  of  711
# Processing image ./images/adidas_41.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_41.png
# processin image  179  of  711
# Processing image ./images/adidas_42.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_42.png
# processin image  180  of  711
# Processing image ./images/adidas_43.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_43.png
# processin image  181  of  711
# Processing image ./images/adidas_44.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_44.png
# processin image  182  of  711
# Processing image ./images/adidas_45.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_45.png
# processin image  183  of  711
# Processing image ./images/adidas_46.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_46.png
# processin image  184  of  711
# Processing image ./images/adidas_47.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_47.png
# processin image  185  of  711
# Processing image ./images/adidas_48.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_48.png
# processin image  186  of  711
# Processing image ./images/adidas_49.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_49.png
# processin image  187  of  711
# Processing image ./images/adidas_50.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_50.png
# processin image  188  of  711
# Processing image ./images/adidas_51.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_51.png
# processin image  189  of  711
# Processing image ./images/adidas_52.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_52.png
# processin image  190  of  711
# Processing image ./images/adidas_53.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_53.png
# processin image  191  of  711
# Processing image ./images/adidas_54.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_54.png
# processin image  192  of  711
# Processing image ./images/adidas_55.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_55.png
# processin image  193  of  711
# Processing image ./images/adidas_56.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_56.png
# processin image  194  of  711
# Processing image ./images/adidas_57.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_57.png
# processin image  195  of  711
# Processing image ./images/adidas_58.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_58.png
# processin image  196  of  711
# Processing image ./images/adidas_59.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_59.png
# processin image  197  of  711
# Processing image ./images/adidas_60.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_60.png
# processin image  198  of  711
# Processing image ./images/adidas_61.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_61.png
# processin image  199  of  711
# Processing image ./images/adidas_62.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_62.png
# processin image  200  of  711
# Processing image ./images/adidas_63.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_63.png
# processin image  201  of  711
# Processing image ./images/adidas_64.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_64.png
# processin image  202  of  711
# Processing image ./images/adidas_65.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_65.png
# processin image  203  of  711
# Processing image ./images/adidas_66.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_66.png
# processin image  204  of  711
# Processing image ./images/adidas_67.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_67.png
# processin image  205  of  711
# Processing image ./images/adidas_68.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_68.png
# processin image  206  of  711
# Processing image ./images/adidas_69.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_69.png
# processin image  207  of  711
# Processing image ./images/adidas_70.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_70.png
# processin image  208  of  711
# Processing image ./images/adidas_71.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_71.png
# processin image  209  of  711
# Processing image ./images/adidas_72.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_72.png
# processin image  210  of  711
# Processing image ./images/adidas_73.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_73.png
# processin image  211  of  711
# Processing image ./images/adidas_74.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_74.png
# processin image  212  of  711
# Processing image ./images/adidas_75.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_75.png
# processin image  213  of  711
# Processing image ./images/adidas_76.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_76.png
# processin image  214  of  711
# Processing image ./images/adidas_77.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_77.png
# processin image  215  of  711
# Processing image ./images/adidas_78.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_78.png
# processin image  216  of  711
# Processing image ./images/adidas_79.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_79.png
# processin image  217  of  711
# Processing image ./images/adidas_80.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_80.png
# processin image  218  of  711
# Processing image ./images/adidas_81.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_81.png
# processin image  219  of  711
# Processing image ./images/adidas_82.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_82.png
# processin image  220  of  711
# Processing image ./images/adidas_83.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_83.png
# processin image  221  of  711
# Processing image ./images/adidas_84.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_84.png
# processin image  222  of  711
# Processing image ./images/adidas_85.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_85.png
# processin image  223  of  711
# Processing image ./images/adidas_86.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_86.png
# processin image  224  of  711
# Processing image ./images/adidas_87.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_87.png
# processin image  225  of  711
# Processing image ./images/adidas_88.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_88.png
# processin image  226  of  711
# Processing image ./images/adidas_89.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_89.png
# processin image  227  of  711
# Processing image ./images/adidas_90.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_90.png
# processin image  228  of  711
# Processing image ./images/adidas_91.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_91.png
# processin image  229  of  711
# Processing image ./images/adidas_92.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_92.png
# processin image  230  of  711
# Processing image ./images/adidas_93.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_93.png
# processin image  231  of  711
# Processing image ./images/adidas_94.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_94.png
# processin image  232  of  711
# Processing image ./images/adidas_95.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_95.png
# processin image  233  of  711
# Processing image ./images/adidas_96.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_96.png
# processin image  234  of  711
# Processing image ./images/adidas_97.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_97.png
# processin image  235  of  711
# Processing image ./images/adidas_98.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_98.png
# processin image  236  of  711
# Processing image ./images/adidas_99.jpg
# .RCBSSaved mask ./annotations/trimaps/adidas_99.png
# processin image  237  of  711
# Processing image ./images/converse_100.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_100.png
# processin image  238  of  711
# Processing image ./images/converse_101.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_101.png
# processin image  239  of  711
# Processing image ./images/converse_102.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_102.png
# processin image  240  of  711
# Processing image ./images/converse_103.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_103.png
# processin image  241  of  711
# Processing image ./images/converse_104.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_104.png
# processin image  242  of  711
# Processing image ./images/converse_105.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_105.png
# processin image  243  of  711
# Processing image ./images/converse_106.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_106.png
# processin image  244  of  711
# Processing image ./images/converse_107.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_107.png
# processin image  245  of  711
# Processing image ./images/converse_108.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_108.png
# processin image  246  of  711
# Processing image ./images/converse_109.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_109.png
# processin image  247  of  711
# Processing image ./images/converse_110.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_110.png
# processin image  248  of  711
# Processing image ./images/converse_111.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_111.png
# processin image  249  of  711
# Processing image ./images/converse_112.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_112.png
# processin image  250  of  711
# Processing image ./images/converse_113.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_113.png
# processin image  251  of  711
# Processing image ./images/converse_114.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_114.png
# processin image  252  of  711
# Processing image ./images/converse_115.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_115.png
# processin image  253  of  711
# Processing image ./images/converse_116.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_116.png
# processin image  254  of  711
# Processing image ./images/converse_117.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_117.png
# processin image  255  of  711
# Processing image ./images/converse_118.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_118.png
# processin image  256  of  711
# Processing image ./images/converse_119.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_119.png
# processin image  257  of  711
# Processing image ./images/converse_120.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_120.png
# processin image  258  of  711
# Processing image ./images/converse_121.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_121.png
# processin image  259  of  711
# Processing image ./images/converse_122.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_122.png
# processin image  260  of  711
# Processing image ./images/converse_123.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_123.png
# processin image  261  of  711
# Processing image ./images/converse_124.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_124.png
# processin image  262  of  711
# Processing image ./images/converse_125.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_125.png
# processin image  263  of  711
# Processing image ./images/converse_126.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_126.png
# processin image  264  of  711
# Processing image ./images/converse_127.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_127.png
# processin image  265  of  711
# Processing image ./images/converse_128.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_128.png
# processin image  266  of  711
# Processing image ./images/converse_129.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_129.png
# processin image  267  of  711
# Processing image ./images/converse_130.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_130.png
# processin image  268  of  711
# Processing image ./images/converse_131.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_131.png
# processin image  269  of  711
# Processing image ./images/converse_132.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_132.png
# processin image  270  of  711
# Processing image ./images/converse_133.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_133.png
# processin image  271  of  711
# Processing image ./images/converse_134.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_134.png
# processin image  272  of  711
# Processing image ./images/converse_135.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_135.png
# processin image  273  of  711
# Processing image ./images/converse_136.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_136.png
# processin image  274  of  711
# Processing image ./images/converse_137.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_137.png
# processin image  275  of  711
# Processing image ./images/converse_138.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_138.png
# processin image  276  of  711
# Processing image ./images/converse_139.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_139.png
# processin image  277  of  711
# Processing image ./images/converse_140.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_140.png
# processin image  278  of  711
# Processing image ./images/converse_141.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_141.png
# processin image  279  of  711
# Processing image ./images/converse_142.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_142.png
# processin image  280  of  711
# Processing image ./images/converse_143.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_143.png
# processin image  281  of  711
# Processing image ./images/converse_144.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_144.png
# processin image  282  of  711
# Processing image ./images/converse_145.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_145.png
# processin image  283  of  711
# Processing image ./images/converse_146.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_146.png
# processin image  284  of  711
# Processing image ./images/converse_147.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_147.png
# processin image  285  of  711
# Processing image ./images/converse_148.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_148.png
# processin image  286  of  711
# Processing image ./images/converse_149.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_149.png
# processin image  287  of  711
# Processing image ./images/converse_150.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_150.png
# processin image  288  of  711
# Processing image ./images/converse_151.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_151.png
# processin image  289  of  711
# Processing image ./images/converse_152.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_152.png
# processin image  290  of  711
# Processing image ./images/converse_153.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_153.png
# processin image  291  of  711
# Processing image ./images/converse_154.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_154.png
# processin image  292  of  711
# Processing image ./images/converse_155.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_155.png
# processin image  293  of  711
# Processing image ./images/converse_156.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_156.png
# processin image  294  of  711
# Processing image ./images/converse_157.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_157.png
# processin image  295  of  711
# Processing image ./images/converse_158.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_158.png
# processin image  296  of  711
# Processing image ./images/converse_159.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_159.png
# processin image  297  of  711
# Processing image ./images/converse_160.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_160.png
# processin image  298  of  711
# Processing image ./images/converse_161.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_161.png
# processin image  299  of  711
# Processing image ./images/converse_162.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_162.png
# processin image  300  of  711
# Processing image ./images/converse_163.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_163.png
# processin image  301  of  711
# Processing image ./images/converse_164.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_164.png
# processin image  302  of  711
# Processing image ./images/converse_165.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_165.png
# processin image  303  of  711
# Processing image ./images/converse_166.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_166.png
# processin image  304  of  711
# Processing image ./images/converse_167.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_167.png
# processin image  305  of  711
# Processing image ./images/converse_168.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_168.png
# processin image  306  of  711
# Processing image ./images/converse_169.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_169.png
# processin image  307  of  711
# Processing image ./images/converse_170.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_170.png
# processin image  308  of  711
# Processing image ./images/converse_171.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_171.png
# processin image  309  of  711
# Processing image ./images/converse_172.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_172.png
# processin image  310  of  711
# Processing image ./images/converse_173.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_173.png
# processin image  311  of  711
# Processing image ./images/converse_174.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_174.png
# processin image  312  of  711
# Processing image ./images/converse_175.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_175.png
# processin image  313  of  711
# Processing image ./images/converse_176.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_176.png
# processin image  314  of  711
# Processing image ./images/converse_177.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_177.png
# processin image  315  of  711
# Processing image ./images/converse_178.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_178.png
# processin image  316  of  711
# Processing image ./images/converse_179.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_179.png
# processin image  317  of  711
# Processing image ./images/converse_180.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_180.png
# processin image  318  of  711
# Processing image ./images/converse_181.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_181.png
# processin image  319  of  711
# Processing image ./images/converse_182.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_182.png
# processin image  320  of  711
# Processing image ./images/converse_183.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_183.png
# processin image  321  of  711
# Processing image ./images/converse_184.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_184.png
# processin image  322  of  711
# Processing image ./images/converse_185.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_185.png
# processin image  323  of  711
# Processing image ./images/converse_186.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_186.png
# processin image  324  of  711
# Processing image ./images/converse_187.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_187.png
# processin image  325  of  711
# Processing image ./images/converse_188.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_188.png
# processin image  326  of  711
# Processing image ./images/converse_189.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_189.png
# processin image  327  of  711
# Processing image ./images/converse_190.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_190.png
# processin image  328  of  711
# Processing image ./images/converse_191.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_191.png
# processin image  329  of  711
# Processing image ./images/converse_192.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_192.png
# processin image  330  of  711
# Processing image ./images/converse_193.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_193.png
# processin image  331  of  711
# Processing image ./images/converse_194.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_194.png
# processin image  332  of  711
# Processing image ./images/converse_195.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_195.png
# processin image  333  of  711
# Processing image ./images/converse_196.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_196.png
# processin image  334  of  711
# Processing image ./images/converse_197.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_197.png
# processin image  335  of  711
# Processing image ./images/converse_198.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_198.png
# processin image  336  of  711
# Processing image ./images/converse_199.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_199.png
# processin image  337  of  711
# Processing image ./images/converse_200.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_200.png
# processin image  338  of  711
# Processing image ./images/converse_201.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_201.png
# processin image  339  of  711
# Processing image ./images/converse_202.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_202.png
# processin image  340  of  711
# Processing image ./images/converse_203.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_203.png
# processin image  341  of  711
# Processing image ./images/converse_204.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_204.png
# processin image  342  of  711
# Processing image ./images/converse_205.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_205.png
# processin image  343  of  711
# Processing image ./images/converse_206.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_206.png
# processin image  344  of  711
# Processing image ./images/converse_207.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_207.png
# processin image  345  of  711
# Processing image ./images/converse_208.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_208.png
# processin image  346  of  711
# Processing image ./images/converse_209.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_209.png
# processin image  347  of  711
# Processing image ./images/converse_210.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_210.png
# processin image  348  of  711
# Processing image ./images/converse_211.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_211.png
# processin image  349  of  711
# Processing image ./images/converse_212.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_212.png
# processin image  350  of  711
# Processing image ./images/converse_213.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_213.png
# processin image  351  of  711
# Processing image ./images/converse_214.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_214.png
# processin image  352  of  711
# Processing image ./images/converse_215.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_215.png
# processin image  353  of  711
# Processing image ./images/converse_216.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_216.png
# processin image  354  of  711
# Processing image ./images/converse_217.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_217.png
# processin image  355  of  711
# Processing image ./images/converse_218.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_218.png
# processin image  356  of  711
# Processing image ./images/converse_219.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_219.png
# processin image  357  of  711
# Processing image ./images/converse_220.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_220.png
# processin image  358  of  711
# Processing image ./images/converse_221.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_221.png
# processin image  359  of  711
# Processing image ./images/converse_222.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_222.png
# processin image  360  of  711
# Processing image ./images/converse_223.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_223.png
# processin image  361  of  711
# Processing image ./images/converse_224.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_224.png
# processin image  362  of  711
# Processing image ./images/converse_225.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_225.png
# processin image  363  of  711
# Processing image ./images/converse_226.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_226.png
# processin image  364  of  711
# Processing image ./images/converse_227.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_227.png
# processin image  365  of  711
# Processing image ./images/converse_228.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_228.png
# processin image  366  of  711
# Processing image ./images/converse_229.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_229.png
# processin image  367  of  711
# Processing image ./images/converse_230.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_230.png
# processin image  368  of  711
# Processing image ./images/converse_231.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_231.png
# processin image  369  of  711
# Processing image ./images/converse_232.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_232.png
# processin image  370  of  711
# Processing image ./images/converse_233.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_233.png
# processin image  371  of  711
# Processing image ./images/converse_234.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_234.png
# processin image  372  of  711
# Processing image ./images/converse_235.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_235.png
# processin image  373  of  711
# Processing image ./images/converse_236.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_236.png
# processin image  374  of  711
# Processing image ./images/converse_237.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_237.png
# processin image  375  of  711
# Processing image ./images/converse_238.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_238.png
# processin image  376  of  711
# Processing image ./images/converse_239.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_239.png
# processin image  377  of  711
# Processing image ./images/converse_240.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_240.png
# processin image  378  of  711
# Processing image ./images/converse_241.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_241.png
# processin image  379  of  711
# Processing image ./images/converse_242.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_242.png
# processin image  380  of  711
# Processing image ./images/converse_243.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_243.png
# processin image  381  of  711
# Processing image ./images/converse_244.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_244.png
# processin image  382  of  711
# Processing image ./images/converse_245.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_245.png
# processin image  383  of  711
# Processing image ./images/converse_246.jpg
# .RCBSSaved mask ./annotations/trimaps/converse_246.png
# processin image  384  of  711
# ...
# processin image  577  of  711
# Processing image ./images/nike_203.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_203.png
# processin image  578  of  711
# Processing image ./images/nike_204.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_204.png
# processin image  579  of  711
# Processing image ./images/nike_205.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_205.png
# processin image  580  of  711
# Processing image ./images/nike_206.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_206.png
# processin image  581  of  711
# Processing image ./images/nike_207.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_207.png
# processin image  582  of  711
# Processing image ./images/nike_208.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_208.png
# processin image  583  of  711
# Processing image ./images/nike_209.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_209.png
# processin image  584  of  711
# Processing image ./images/nike_210.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_210.png
# processin image  585  of  711
# Processing image ./images/nike_211.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_211.png
# processin image  586  of  711
# Processing image ./images/nike_212.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_212.png
# processin image  587  of  711
# Processing image ./images/nike_213.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_213.png
# processin image  588  of  711
# Processing image ./images/nike_214.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_214.png
# processin image  589  of  711
# Processing image ./images/nike_215.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_215.png
# processin image  590  of  711
# Processing image ./images/nike_216.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_216.png
# processin image  591  of  711
# Processing image ./images/nike_217.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_217.png
# processin image  592  of  711
# Processing image ./images/nike_218.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_218.png
# processin image  593  of  711
# Processing image ./images/nike_219.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_219.png
# processin image  594  of  711
# Processing image ./images/nike_220.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_220.png
# processin image  595  of  711
# Processing image ./images/nike_221.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_221.png
# processin image  596  of  711
# Processing image ./images/nike_222.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_222.png
# processin image  597  of  711
# Processing image ./images/nike_223.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_223.png
# processin image  598  of  711
# Processing image ./images/nike_224.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_224.png
# processin image  599  of  711
# Processing image ./images/nike_225.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_225.png
# processin image  600  of  711
# Processing image ./images/nike_226.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_226.png
# processin image  601  of  711
# Processing image ./images/nike_227.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_227.png
# processin image  602  of  711
# Processing image ./images/nike_228.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_228.png
# processin image  603  of  711
# Processing image ./images/nike_229.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_229.png
# processin image  604  of  711
# Processing image ./images/nike_230.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_230.png
# processin image  605  of  711
# Processing image ./images/nike_231.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_231.png
# processin image  606  of  711
# Processing image ./images/nike_232.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_232.png
# processin image  607  of  711
# Processing image ./images/nike_233.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_233.png
# processin image  608  of  711
# Processing image ./images/nike_234.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_234.png
# processin image  609  of  711
# Processing image ./images/nike_235.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_235.png
# processin image  610  of  711
# Processing image ./images/nike_236.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_236.png
# processin image  611  of  711
# Processing image ./images/nike_237.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_237.png
# processin image  612  of  711
# Processing image ./images/nike_238.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_238.png
# processin image  613  of  711
# Processing image ./images/nike_239.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_239.png
# processin image  614  of  711
# Processing image ./images/nike_240.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_240.png
# processin image  615  of  711
# Processing image ./images/nike_241.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_241.png
# processin image  616  of  711
# Processing image ./images/nike_242.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_242.png
# processin image  617  of  711
# Processing image ./images/nike_243.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_243.png
# processin image  618  of  711
# Processing image ./images/nike_244.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_244.png
# processin image  619  of  711
# Processing image ./images/nike_245.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_245.png
# processin image  620  of  711
# Processing image ./images/nike_246.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_246.png
# processin image  621  of  711
# Processing image ./images/nike_247.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_247.png
# processin image  622  of  711
# Processing image ./images/nike_248.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_248.png
# processin image  623  of  711
# Processing image ./images/nike_249.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_249.png
# processin image  624  of  711
# Processing image ./images/nike_250.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_250.png
# processin image  625  of  711
# Processing image ./images/nike_251.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_251.png
# processin image  626  of  711
# Processing image ./images/nike_252.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_252.png
# processin image  627  of  711
# Processing image ./images/nike_253.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_253.png
# processin image  628  of  711
# Processing image ./images/nike_254.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_254.png
# processin image  629  of  711
# Processing image ./images/nike_255.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_255.png
# processin image  630  of  711
# Processing image ./images/nike_256.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_256.png
# processin image  631  of  711
# Processing image ./images/nike_257.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_257.png
# processin image  632  of  711
# Processing image ./images/nike_258.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_258.png
# processin image  633  of  711
# Processing image ./images/nike_259.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_259.png
# processin image  634  of  711
# Processing image ./images/nike_260.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_260.png
# processin image  635  of  711
# Processing image ./images/nike_261.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_261.png
# processin image  636  of  711
# Processing image ./images/nike_262.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_262.png
# processin image  637  of  711
# Processing image ./images/nike_263.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_263.png
# processin image  638  of  711
# Processing image ./images/nike_264.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_264.png
# processin image  639  of  711
# Processing image ./images/nike_265.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_265.png
# processin image  640  of  711
# Processing image ./images/nike_266.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_266.png
# processin image  641  of  711
# Processing image ./images/nike_267.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_267.png
# processin image  642  of  711
# Processing image ./images/nike_268.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_268.png
# processin image  643  of  711
# Processing image ./images/nike_269.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_269.png
# processin image  644  of  711
# Processing image ./images/nike_270.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_270.png
# processin image  645  of  711
# Processing image ./images/nike_271.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_271.png
# processin image  646  of  711
# Processing image ./images/nike_272.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_272.png
# processin image  647  of  711
# Processing image ./images/nike_273.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_273.png
# processin image  648  of  711
# Processing image ./images/nike_274.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_274.png
# processin image  649  of  711
# Processing image ./images/nike_38.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_38.png
# processin image  650  of  711
# Processing image ./images/nike_39.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_39.png
# processin image  651  of  711
# Processing image ./images/nike_40.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_40.png
# processin image  652  of  711
# Processing image ./images/nike_41.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_41.png
# processin image  653  of  711
# Processing image ./images/nike_42.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_42.png
# processin image  654  of  711
# Processing image ./images/nike_43.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_43.png
# processin image  655  of  711
# Processing image ./images/nike_44.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_44.png
# processin image  656  of  711
# Processing image ./images/nike_45.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_45.png
# processin image  657  of  711
# Processing image ./images/nike_46.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_46.png
# processin image  658  of  711
# Processing image ./images/nike_47.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_47.png
# processin image  659  of  711
# Processing image ./images/nike_48.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_48.png
# processin image  660  of  711
# Processing image ./images/nike_49.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_49.png
# processin image  661  of  711
# Processing image ./images/nike_50.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_50.png
# processin image  662  of  711
# Processing image ./images/nike_51.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_51.png
# processin image  663  of  711
# Processing image ./images/nike_52.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_52.png
# processin image  664  of  711
# Processing image ./images/nike_53.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_53.png
# processin image  665  of  711
# Processing image ./images/nike_54.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_54.png
# processin image  666  of  711
# Processing image ./images/nike_55.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_55.png
# processin image  667  of  711
# Processing image ./images/nike_56.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_56.png
# processin image  668  of  711
# Processing image ./images/nike_57.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_57.png
# processin image  669  of  711
# Processing image ./images/nike_58.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_58.png
# processin image  670  of  711
# Processing image ./images/nike_59.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_59.png
# processin image  671  of  711
# Processing image ./images/nike_60.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_60.png
# processin image  672  of  711
# Processing image ./images/nike_61.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_61.png
# processin image  673  of  711
# Processing image ./images/nike_62.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_62.png
# processin image  674  of  711
# Processing image ./images/nike_63.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_63.png
# processin image  675  of  711
# Processing image ./images/nike_64.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_64.png
# processin image  676  of  711
# Processing image ./images/nike_65.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_65.png
# processin image  677  of  711
# Processing image ./images/nike_66.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_66.png
# processin image  678  of  711
# Processing image ./images/nike_67.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_67.png
# processin image  679  of  711
# Processing image ./images/nike_68.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_68.png
# processin image  680  of  711
# Processing image ./images/nike_69.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_69.png
# processin image  681  of  711
# Processing image ./images/nike_70.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_70.png
# processin image  682  of  711
# Processing image ./images/nike_71.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_71.png
# processin image  683  of  711
# Processing image ./images/nike_72.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_72.png
# processin image  684  of  711
# Processing image ./images/nike_73.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_73.png
# processin image  685  of  711
# Processing image ./images/nike_74.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_74.png
# processin image  686  of  711
# Processing image ./images/nike_75.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_75.png
# processin image  687  of  711
# Processing image ./images/nike_76.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_76.png
# processin image  688  of  711
# Processing image ./images/nike_77.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_77.png
# processin image  689  of  711
# Processing image ./images/nike_78.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_78.png
# processin image  690  of  711
# Processing image ./images/nike_79.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_79.png
# processin image  691  of  711
# Processing image ./images/nike_80.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_80.png
# processin image  692  of  711
# Processing image ./images/nike_81.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_81.png
# processin image  693  of  711
# Processing image ./images/nike_82.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_82.png
# processin image  694  of  711
# Processing image ./images/nike_83.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_83.png
# processin image  695  of  711
# Processing image ./images/nike_84.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_84.png
# processin image  696  of  711
# Processing image ./images/nike_85.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_85.png
# processin image  697  of  711
# Processing image ./images/nike_86.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_86.png
# processin image  698  of  711
# Processing image ./images/nike_87.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_87.png
# processin image  699  of  711
# Processing image ./images/nike_88.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_88.png
# processin image  700  of  711
# Processing image ./images/nike_89.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_89.png
# processin image  701  of  711
# Processing image ./images/nike_90.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_90.png
# processin image  702  of  711
# Processing image ./images/nike_91.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_91.png
# processin image  703  of  711
# Processing image ./images/nike_92.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_92.png
# processin image  704  of  711
# Processing image ./images/nike_93.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_93.png
# processin image  705  of  711
# Processing image ./images/nike_94.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_94.png
# processin image  706  of  711
# Processing image ./images/nike_95.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_95.png
# processin image  707  of  711
# Processing image ./images/nike_96.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_96.png
# processin image  708  of  711
# Processing image ./images/nike_97.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_97.png
# processin image  709  of  711
# Processing image ./images/nike_98.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_98.png
# processin image  710  of  711
# Processing image ./images/nike_99.jpg
# .RCBSSaved mask ./annotations/trimaps/nike_99.png
